# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
##Write your code here
# Split the semicolon-separated database lists and count each database
db_series = df['DatabaseWantToWorkWith'].dropna().str.split(';')
db_flat = db_series.explode().str.strip()

# Get the top 5 most-desired databases
top5_db = db_flat.value_counts().head(5)

# Plot the pie chart
plt.figure(figsize=(7,7))
plt.pie(top5_db, labels=top5_db.index, autopct='%1.1f%%', startangle=140, counterclock=False)
plt.title('Top 5 Databases Respondents Want to Work With')
plt.axis('equal')
plt.show()

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
##Write your code here
# Split the semicolon-separated developer type lists and count each type
devtype_series = df['DevType'].dropna().str.split(';')
devtype_flat = devtype_series.explode().str.strip()

# Get the top 5 most common developer roles
top5_devtype = devtype_flat.value_counts().head(5)

# Plot the pie chart
plt.figure(figsize=(7,7))
plt.pie(top5_devtype, labels=top5_devtype.index, autopct='%1.1f%%', startangle=140, counterclock=False)
plt.title('Top 5 Developer Roles Among Respondents')
plt.axis('equal')
# Out:
# (np.float64(-1.0999993292259875),
#  np.float64(1.0999858493656607),
#  np.float64(-1.0999994866667957),
#  np.float64(1.0999952788429477))

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
os_series = df['OpSysProfessional use'].dropna().str.split(';')
os_flat = os_series.explode().str.strip()
top_os = os_flat.value_counts()
plt.figure(figsize=(7,7))
plt.pie(top_os, labels=top_os.index, autopct='%1.1f%%', startangle=140, counterclock=False)
plt.title('Operating Systems Used Professionally by Respondents')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
##Write your code here
# Split the semicolon-separated language lists and count each language
lang_series = df['LanguageHaveWorkedWith'].dropna().str.split(';')
lang_flat = lang_series.explode().str.strip()

# Get the top 5 most common programming languages
top5_lang = lang_flat.value_counts().head(5)

# Plot the pie chart
plt.figure(figsize=(7,7))
plt.pie(top5_lang, labels=top5_lang.index, autopct='%1.1f%%', startangle=140, counterclock=False)
plt.title('Top 5 Programming Languages Respondents Have Worked With')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %%
# Split the semicolon-separated collaboration tool lists and count each tool
collab_series = df['NEWCollabToolsHaveWorkedWith'].dropna().str.split(';')
collab_flat = collab_series.explode().str.strip()

# Get the top 5 most common collaboration tools
top5_collab = collab_flat.value_counts().head(5)

# Plot the pie chart
plt.figure(figsize=(7,7))
plt.pie(top5_collab, labels=top5_collab.index, autopct='%1.1f%%', startangle=140, counterclock=False)
plt.title('Top 5 Collaboration Tools Used Professionally')
plt.axis
# Out:
# <function matplotlib.pyplot.axis(arg: 'tuple[float, float, float, float] | bool | str | None' = None, /, *, emit: 'bool' = True, **kwargs) -> 'tuple[float, float, float, float]'>

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
##Write your code here
# Split the semicolon-separated collaboration tool lists and count each tool
collab_series = df['NEWCollabToolsHaveWorkedWith'].dropna().str.split(';')
collab_flat = collab_series.explode().str.strip()

# Get the top 5 most common collaboration tools
top5_collab = collab_flat.value_counts().head(5)

# Plot the pie chart
plt.figure(figsize=(7,7))
plt.pie(top5_collab, labels=top5_collab.index, autopct='%1.1f%%', startangle=140, counterclock=False)
plt.title('Top 5 Collaboration Tools Used Professionally')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
##Write your code here
# Split the semicolon-separated admired language lists and count each language
admired_series = df['LanguageAdmired'].dropna().str.split(';')
admired_flat = admired_series.explode().str.strip()

# Get the top 5 most admired programming languages
top5_admired = admired_flat.value_counts().head(5)

# Plot the pie chart
plt.figure(figsize=(7,7))
plt.pie(top5_admired, labels=top5_admired.index, autopct='%1.1f%%', startangle=140, counterclock=False)
plt.title('Top 5 Most Admired Programming Languages')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
##Write your code here
# Split the semicolon-separated AI tool lists and count each tool
ai_tool_series = df['AIToolCurrently Using'].dropna().str.split(';')
ai_tool_flat = ai_tool_series.explode().str.strip()

# Get the top 5 most common AI tools
top5_ai_tools = ai_tool_flat.value_counts().head(5)

# Plot the pie chart
plt.figure(figsize=(7,7))
plt.pie(top5_ai_tools, labels=top5_ai_tools.index, autopct='%1.1f%%', startangle=140, counterclock=False)
plt.title('Top 5 AI Tools Currently Used by Developers')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
##Write your code here
# Split the semicolon-separated web framework lists and count each framework
webframe_series = df['WebframeWantToWorkWith'].dropna().str.split(';')
webframe_flat = webframe_series.explode().str.strip()

# Get the top 5 most desired web frameworks
top5_webframes = webframe_flat.value_counts().head(5)

# Plot the pie chart
plt.figure(figsize=(7,7))
plt.pie(top5_webframes, labels=top5_webframes.index, autopct='%1.1f%%', startangle=140, counterclock=False)
plt.title('Top 5 Web Frameworks Respondents Want to Work With')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
##Write your code here
# Split the semicolon-separated embedded technology lists and count each technology
embedded_series = df['EmbeddedWantToWorkWith'].dropna().str.split(';')
embedded_flat = embedded_series.explode().str.strip()

# Get the top 5 most desired embedded technologies
top5_embedded = embedded_flat.value_counts().head(5)

# Plot the pie chart
plt.figure(figsize=(7,7))
plt.pie(top5_embedded, labels=top5_embedded.index, autopct='%1.1f%%', startangle=140, counterclock=False)
plt.title('Top 5 Embedded Technologies Respondents Want to Work With')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
